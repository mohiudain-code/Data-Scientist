# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor

# %%
df=pd.read_csv('multiple_linear_regression_dataset.csv')
df.head()
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580
# 3   32           5   40130
# 4   43          10   47830

# %%
sns.distplot(df["income"])
plt.show()
# Out:
# C:\Users\DEll\AppData\Local\Temp\ipykernel_11144\506665599.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["income"])

# %%
x=df.iloc[:,:-1]
y=df['income']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
Knn=KNeighborsRegressor(n_neighbors=2)
Knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
Knn.score(x_test,y_test)*100,Knn.score(x_train,y_train)*100
# Out:
# (40.90505083594478, 80.42364818689664)

# %%
for i in range(1,16):
    Knn=KNeighborsRegressor(n_neighbors=i)
    Knn.fit(x_train,y_train)
    print(Knn.score(x_test,y_test)*100,Knn.score(x_train,y_train)*100)
# Out:
# -17.43059084993139 100.0
# 40.90505083594478 80.42364818689664
# 20.178426953421603 72.73125676751762
# 1.5972494875457377 58.6847456018583
# 3.539517791175595 57.733138932105945
# -1.806918152643533 48.764528650567065
# -4.9565191587197965 41.3522448901896
# -2.1857300957785597 29.28756132461463
# -19.941773114305896 20.00771872317795
# -33.812500752723665 18.244620121289955
# -21.449665038222278 9.566264354232345
# -38.74180389878297 10.490351807918074
# -48.21314889583446 10.251612965341506
# -35.99043022169373 8.507183785115247
# -28.835529234537738 6.801747647260214
