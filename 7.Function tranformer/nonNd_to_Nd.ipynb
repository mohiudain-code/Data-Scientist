# %%
import pandas as pd
df=pd.read_csv('train_update.csv')
df.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1.0        60.0       RL         65.0   8450.0   Pave   NaN      Reg
# 1  2.0        20.0       RL          NaN   9600.0   Pave   NaN      Reg
# 2  3.0        60.0       RL         68.0      NaN   Pave   NaN      IR1
# 3  4.0        70.0       RL         60.0      NaN   Pave   NaN      NaN
# 4  5.0        60.0       RL         84.0  14260.0    NaN   NaN      NaN
#
#   Unnamed: 8 Unnamed: 9  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0        NaN     AllPub  ...        0    NaN   NaN         NaN       0      2
# 1        Lvl     AllPub  ...        0    NaN   NaN         NaN       0      5
# 2        NaN     AllPub  ...        0    NaN   NaN         NaN       0      9
# 3        Lvl     AllPub  ...        0    NaN   NaN         NaN       0      2
# 4        Lvl     AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold SaleType  SaleCondition  SalePrice
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot(df['SalePrice'])
plt.show()
# Out:
# C:\Users\DEll\AppData\Local\Temp\ipykernel_21108\941020751.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SalePrice'])

# %%
q1=df['SalePrice'].quantile(0.25)
q3=df['SalePrice'].quantile(0.75)

# %%
iqr=q3-q1
min_r= q1-(1.5*iqr)
max_r= q3+(1.5*iqr)
max_r
# Out:
# np.float64(340037.5)

# %%
df=(df[df['SalePrice']<=max_r])

sns.distplot(df['SalePrice'])
plt.show()

df.head(5)
# Out:
# C:\Users\DEll\AppData\Local\Temp\ipykernel_21108\3076067355.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SalePrice'])
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1.0        60.0       RL         65.0   8450.0   Pave   NaN      Reg
# 1  2.0        20.0       RL          NaN   9600.0   Pave   NaN      Reg
# 2  3.0        60.0       RL         68.0      NaN   Pave   NaN      IR1
# 3  4.0        70.0       RL         60.0      NaN   Pave   NaN      NaN
# 4  5.0        60.0       RL         84.0  14260.0    NaN   NaN      NaN
#
# ...

# %%
from sklearn.preprocessing import FunctionTransformer
import numpy as np
ft=FunctionTransformer(func=lambda x:x**2)
ft.fit(df[['SalePrice']])
df['SalePrice_FT']=ft.transform(df[['SalePrice']])
df
# Out:
#           Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1.0        60.0       RL         65.0   8450.0   Pave   NaN      Reg
# 1        2.0        20.0       RL          NaN   9600.0   Pave   NaN      Reg
# 2        3.0        60.0       RL         68.0      NaN   Pave   NaN      IR1
# 3        4.0        70.0       RL         60.0      NaN   Pave   NaN      NaN
# 4        5.0        60.0       RL         84.0  14260.0    NaN   NaN      NaN
# ...      ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456.0        60.0       RL         62.0   7917.0   Pave   NaN      Reg
# 1456  1457.0        20.0       RL         85.0  13175.0   Pave   NaN      Reg
# 1457  1458.0        70.0       RL         66.0   9042.0   Pave   NaN      Reg
# 1458  1459.0        20.0       RL         68.0   9717.0   Pave   NaN      Reg
# 1459  1460.0        20.0       RL         75.0   9937.0   Pave   NaN      Reg
#
# ...

# %%
plt.subplot(1,2,1)
sns.distplot(df['SalePrice'])
plt.title('Non-Normal Distribution')
plt.subplot(1,2,2)
sns.distplot(df['SalePrice_FT'])
plt.title('Normal Distribution')
plt.show()
# Out:
# C:\Users\DEll\AppData\Local\Temp\ipykernel_21108\4074125886.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SalePrice'])
# C:\Users\DEll\AppData\Local\Temp\ipykernel_21108\4074125886.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SalePrice_FT'])

# %%
from sklearn.preprocessing import FunctionTransformer
import numpy as np
ft=FunctionTransformer(func=np.log1p)
ft.fit(df[['SalePrice']])
df['SalePrice_FT']=ft.transform(df[['SalePrice']])

# %%
plt.subplot(1,2,1)
sns.distplot(df['SalePrice'])
plt.title('Non-Normal Distribution')
plt.subplot(1,2,2)
sns.distplot(df['SalePrice_FT'])
plt.title('Normal Distribution')
plt.show()
# Out:
# C:\Users\DEll\AppData\Local\Temp\ipykernel_21108\4074125886.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SalePrice'])
# C:\Users\DEll\AppData\Local\Temp\ipykernel_21108\4074125886.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SalePrice_FT'])
