# %%
import pandas as pd

# %%
df=pd.read_csv('train_update.csv')
df.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1.0        60.0       RL         65.0   8450.0   Pave   NaN      Reg
# 1  2.0        20.0       RL          NaN   9600.0   Pave   NaN      Reg
# 2  3.0        60.0       RL         68.0      NaN   Pave   NaN      IR1
# 3  4.0        70.0       RL         60.0      NaN   Pave   NaN      NaN
# 4  5.0        60.0       RL         84.0  14260.0    NaN   NaN      NaN
#
#   Unnamed: 8 Unnamed: 9  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0        NaN     AllPub  ...        0    NaN   NaN         NaN       0      2
# 1        Lvl     AllPub  ...        0    NaN   NaN         NaN       0      5
# 2        NaN     AllPub  ...        0    NaN   NaN         NaN       0      9
# 3        Lvl     AllPub  ...        0    NaN   NaN         NaN       0      2
# 4        Lvl     AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1454 non-null   float64
#  1   MSSubClass     1455 non-null   float64
#  2   MSZoning       1450 non-null   object
#  3   LotFrontage    1196 non-null   float64
#  4   LotArea        1451 non-null   float64
#  5   Street         1450 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1444 non-null   object
#  8   Unnamed: 8     1451 non-null   object
#  9   Unnamed: 9     1452 non-null   object
#  10  LotConfig      1455 non-null   object
#  11  LandSlope      1454 non-null   object
#  12  Neighborhood   1455 non-null   object
#  13  Condition1     1456 non-null   object
#  14  Condition2     1455 non-null   object
#  15  BldgType       1457 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
df['OverallQual'].value_counts()
# Out:
# OverallQual
# 5     397
# 6     374
# 7     319
# 8     167
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# 11      1
# Name: count, dtype: int64

# %%
df['OverallQual'].fillna(df['OverallQual'].mode()[0],inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1454 non-null   float64
#  1   MSSubClass     1455 non-null   float64
#  2   MSZoning       1450 non-null   object
#  3   LotFrontage    1196 non-null   float64
#  4   LotArea        1451 non-null   float64
#  5   Street         1450 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1444 non-null   object
#  8   Unnamed: 8     1451 non-null   object
#  9   Unnamed: 9     1452 non-null   object
#  10  LotConfig      1455 non-null   object
#  11  LandSlope      1454 non-null   object
#  12  Neighborhood   1455 non-null   object
#  13  Condition1     1456 non-null   object
#  14  Condition2     1455 non-null   object
#  15  BldgType       1457 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
df['OverallQual'].replace('5+','11',inplace=True)

# %%
df['OverallQual']=df['OverallQual'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1454 non-null   float64
#  1   MSSubClass     1455 non-null   float64
#  2   MSZoning       1450 non-null   object
#  3   LotFrontage    1196 non-null   float64
#  4   LotArea        1451 non-null   float64
#  5   Street         1450 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1444 non-null   object
#  8   Unnamed: 8     1451 non-null   object
#  9   Unnamed: 9     1452 non-null   object
#  10  LotConfig      1455 non-null   object
#  11  LandSlope      1454 non-null   object
#  12  Neighborhood   1455 non-null   object
#  13  Condition1     1456 non-null   object
#  14  Condition2     1455 non-null   object
#  15  BldgType       1457 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...
