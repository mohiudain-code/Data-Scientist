# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from mlxtend.plotting import plot_decision_regions

# %%
df=pd.read_csv('Social_Network_Ads.csv')
df.head(3)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0

# %%
sns.scatterplot(x="Age",y="EstimatedSalary",data=df,hue="Purchased")
plt.show()

# %%
x=df.iloc[:,:-1]
y=df["Purchased"]

# %% [markdown]
# # Pre Pruning

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
dt=DecisionTreeClassifier(max_depth=4)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
dt.score(x_test,y_test)*100,dt.score(x_train,y_train)*100
# Out:
# (91.25, 93.125)

# %%
plot_tree(dt)
plt.show()

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dt)
plt.show()
# Out:
# C:\Users\DEll\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Post Pruning

# %%
x_train1,x_test1,y_train1,y_test1=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
for i in range(1,15):
    dt=DecisionTreeClassifier(max_depth=i)
    dt.fit(x_train1,y_train1)
    print(dt.score(x_test1,y_test1)*100,dt.score(x_train1,y_train1)*100)
# Out:
# 90.0 82.1875
# 91.25 91.875
# 91.25 91.875
# 91.25 93.125
# 90.0 93.4375
# 86.25 95.0
# 85.0 96.875
# 85.0 97.1875
# 85.0 98.125
# 85.0 98.4375
# 83.75 99.0625
# 83.75 99.375
# 83.75 99.6875
# 83.75 99.6875

# %%
dt=DecisionTreeClassifier(max_depth=3)
dt.fit(x_train1,y_train1)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
dt.score(x_test1,y_test1)*100,dt.score(x_train1,y_train1)*100
# Out:
# (91.25, 91.875)

# %%
plot_tree(dt)
plt.show()

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dt)
plt.show()
# Out:
# C:\Users\DEll\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
