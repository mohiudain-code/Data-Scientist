# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('multiple_linear_regression_dataset.csv')
df.head(3)
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580

# %%
sns.pairplot(data=df)
plt.show()

# %%
sns.heatmap(data=df.corr(),annot=True)
plt.show()

# %%
x=df.iloc[:,:-1]
y=df['income']

# %%
df.shape
# Out:
# (20, 3)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=42)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 93.44104202690177

# %%
lr.predict([[25,1]])
# Out:
# c:\Users\DEll\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([31256.03513867])

# %%
lr.coef_
# Out:
# array([-106.38655188, 2149.68940017])

# %%
lr.intercept_
# Out:
# np.float64(31766.009535472178)

# %%
m1=-106.38655188
m2=2149.68940017
c=31766.009535472178
y=m1*25+m2*1+c
y
# Out:
# 31256.03513864218

# %%
sns.scatterplot(x='experience',y='income',data=df)
plt.plot(df['experience'],lr.predict(x),c='gray')
plt.legend(['org','predict line'])
plt.show()
